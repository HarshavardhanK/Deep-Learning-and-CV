# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv.imread("messi.jpg")

# %%
px = img[100,100]
print(px)
# Out:
# [142 126 127]

# %%
blue = img[100, 100, 0]
print(blue)
# Out:
# 142

# %% [markdown]
# #### Accessing red values

# %%
img.item(10, 10, 2)
# Out:
# 136

# %%
img.itemset((10, 10, 2), 100)
img.item(10, 10, 2)
# Out:
# 100

# %% [markdown]
# ### Accessing image properties

# %%
print("Shape of the image {}".format(img.shape))
print("Size of the image {}".format(img.size))
print(img.dtype)
# Out:
# Shape of the image (433, 770, 3)
# Size of the image 1000230
# uint8

# %% [markdown]
# ### Image ROI

# %%
region = img[300:200, 323:323]
print(region)
# Out:
# []

# %% [markdown]
# ### Splitting and merging image channels

# %%
blue, green, red = cv.split(img)
plt.imshow(blue)
#plt.imshow(green)
#plt.imshow(red)
